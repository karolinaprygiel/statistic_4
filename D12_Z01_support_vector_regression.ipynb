# %% [markdown]
# # Support vector regression (SVR)

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt

from sklearn.svm import SVR

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # kernel='linear'

# %%
x=np.vstack(x)
x_plot = np.vstack(np.linspace(0, 10, 1000))
svr_lin_1 = SVR(kernel='linear', C=1000)
y_rbf = svr_lin_1.fit(x, y)
# Plot outputs
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
plt.plot(x_plot, svr_lin_1.predict(x_plot), color='blue',linewidth=3)
plt.show()

# %%
svr_lin_2 = SVR(kernel='linear', C=10)
y_rbf = svr_lin_2.fit(x, y)
# Plot outputs
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
plt.plot(x_plot, svr_lin_2.predict(x_plot), color='blue',linewidth=3)
plt.show()

# %% [markdown]
# # kernel='poly'

# %%
svr_poly_1 = SVR(kernel='poly', C=1e3, degree=2)
y_rbf = svr_poly_1.fit(x, y)
# Plot outputs
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
plt.plot(x_plot, svr_poly_1.predict(x_plot), color='b', linewidth=3)
plt.show()

# %%
svr_poly_2 = SVR(kernel='poly', C=1e3, degree=3)
y_rbf = svr_poly_2.fit(x, y)
# Plot outputs
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
plt.plot(x_plot, svr_poly_2.predict(x_plot), color='b', linewidth=3)
plt.show()

# %% [markdown]
# # kernel='rbf'

# %%
svr_rbf_1 = SVR(kernel='rbf', C=10, gamma=100)
y_rbf = svr_rbf_1.fit(x, y)
# Plot outputs
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
plt.plot(x_plot, svr_rbf_1.predict(x_plot), color='b',linewidth=3)
plt.show()

# %%
svr_rbf_2 = SVR(kernel='rbf', C=10**6, gamma=1.1)
y_rbf = svr_rbf_2.fit(x, y)
# Plot outputs
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
plt.plot(x_plot, svr_rbf_2.predict(x_plot), color='b',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najlepsza?

# %%
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_plot, svr_lin_1.predict(x_plot), 'g');
plt.plot(x_plot, svr_lin_2.predict(x_plot), 'b');
plt.plot(x_plot, svr_poly_1.predict(x_plot), 'c');
plt.plot(x_plot, svr_poly_2.predict(x_plot), 'g');
plt.plot(x_plot, svr_rbf_1.predict(x_plot), 'c');
plt.plot(x_plot, svr_rbf_2.predict(x_plot), 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
from sklearn import  metrics
regressors = {}
regressors['svr_lin_1'] = svr_lin_1
regressors['svr_lin_1'] = svr_lin_2
regressors['svr_poly_1'] = svr_poly_1
regressors['svr_poly_2'] = svr_poly_2
regressors['svr_rbf_1'] = svr_rbf_1
regressors['svr_rbf_2'] = svr_rbf_2

for key in regressors:
    print(key)
    regr = regressors[key]
    print("Explained variance score: {}".format( metrics.explained_variance_score(y, regr.predict(x)) ))
    print("Median absolute error: {}".format( metrics.median_absolute_error(y, regr.predict(x)) ))
    print("Mean squared error: {}".format( metrics.mean_squared_error(y, regr.predict(x)) ))
    print("Mean absolute errors: {}".format(metrics.mean_absolute_error(y, regr.predict(x))))
# Out:
# svr_lin_1
# Explained variance score: 0.2953716316306009
# Median absolute error: 1.1833566762795371
# Mean squared error: 48.00827792581732
# Mean absolute errors: 3.298639171816433
# svr_poly_1
# Explained variance score: 0.5511493990389245
# Median absolute error: 1.6945534682687573
# Mean squared error: 29.611886593521373
# Mean absolute errors: 3.065612228004556
# svr_poly_2
# Explained variance score: 0.8156935087089386
# Median absolute error: 1.7802966171912975
# Mean squared error: 11.913210745348223
# Mean absolute errors: 2.543335559800365
# svr_rbf_1
# Explained variance score: 0.9871538947098906
# Median absolute error: 0.10008529989644699
# Mean squared error: 0.8288695840901713
# Mean absolute errors: 0.22444939966592328
# svr_rbf_2
# Explained variance score: 0.9993843537556449
# Median absolute error: 0.11707202739410227
# Mean squared error: 0.03952091750974405
# Mean absolute errors: 0.15255353637389266
