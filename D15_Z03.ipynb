# %% [markdown]
# # Random Walk

# %%
import numpy as np
import pandas as pd
import scipy
import random
import matplotlib.pylab as plt

# %%
x = [0]
for j in range(1000):
    x.append(x[j] + np.random.normal())

# %%
df=pd.Series(x)
plt.figure(figsize=(12,6));
df.plot()
plt.show()

# %% [markdown]
# # rho=0

# %% [markdown]
# # rho=0.5

# %% [markdown]
# # rho=0.9

# %% [markdown]
# # rho=1

# %% [markdown]
# # rho=1.1
